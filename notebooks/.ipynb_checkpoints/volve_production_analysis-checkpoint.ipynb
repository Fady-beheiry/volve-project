# %%
# %pip install psycopg2-binary openpyxl

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine, text

# Output directories setup
os.makedirs("/home/jovyan/outputs/figures", exist_ok=True)
os.makedirs("/home/jovyan/outputs/tables", exist_ok=True)

# PostgreSQL connection
DB_URI = "postgresql+psycopg2://postgres:password@postgres:5432/production_db"
engine = create_engine(DB_URI)

with engine.connect() as conn:
    res = conn.execute(text("SELECT current_database(), current_user, version();")).fetchone()
    print("Connected successfully to PostgreSQL:")
    print(f"Database: {res[0]} | User: {res[1]}")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Connected successfully to PostgreSQL:
# Database: production_db | User: postgres

# %%
raw_file_path = "/home/jovyan/data/raw/Volve_production_data.xlsx"

daily_raw = pd.read_excel(raw_file_path, sheet_name="Daily Production Data")
monthly_raw = pd.read_excel(raw_file_path, sheet_name="Monthly Production Data")

def preprocess_daily_data(df: pd.DataFrame) -> pd.DataFrame:
    df_clean = df.copy()
    # SCREAMING_SNAKE_CASE column names
    df_clean.columns = [c.strip().replace(" ", "_").replace("-", "_").upper() for c in df_clean.columns]
    
    # DateTime standard
    df_clean["DATEPRD"] = pd.to_datetime(df_clean["DATEPRD"])
    
    # Source row ID tracking
    df_clean["SOURCE_ROW_ID"] = df_clean.index + 1
    
    # Produced water handling: preserve raw, flag invalid negative values, set to NaN
    if "BORE_WAT_VOL" in df_clean.columns:
        df_clean["BORE_WAT_VOL_RAW"] = df_clean["BORE_WAT_VOL"]
        df_clean["IS_INVALID_WATER"] = df_clean["BORE_WAT_VOL"] < 0
        df_clean.loc[df_clean["BORE_WAT_VOL"] < 0, "BORE_WAT_VOL"] = np.nan
        
    return df_clean

clean_daily_df = preprocess_daily_data(daily_raw)
monthly_raw.columns = [c.strip().replace(" ", "_").replace("-", "_").upper() for c in monthly_raw.columns]

# Separate operational domains
production_df = clean_daily_df[clean_daily_df["FLOW_KIND"] == "production"].copy()
injection_df = clean_daily_df[clean_daily_df["FLOW_KIND"] == "injection"].copy()

# Ingest into PostgreSQL
clean_daily_df.to_sql("daily_production", engine, if_exists="replace", index=False)
production_df.to_sql("production_data", engine, if_exists="replace", index=False)
injection_df.to_sql("injection_data", engine, if_exists="replace", index=False)
monthly_raw.to_sql("monthly_production", engine, if_exists="replace", index=False)

print(f"Loaded {len(production_df)} production rows and {len(injection_df)} injection rows into PostgreSQL.")
# Out:
# Loaded 9161 production rows and 6473 injection rows into PostgreSQL.

# %%
# Read analytical data directly from PostgreSQL
prod_db = pd.read_sql("SELECT * FROM production_data", engine)
inj_db = pd.read_sql("SELECT * FROM injection_data", engine)
prod_db["DATEPRD"] = pd.to_datetime(prod_db["DATEPRD"])

# Derived metrics
prod_db["WATER_CUT"] = prod_db["BORE_WAT_VOL"] / (prod_db["BORE_OIL_VOL"] + prod_db["BORE_WAT_VOL"]).replace(0, np.nan)
prod_db["OIL_PER_ON_STREAM_HR"] = prod_db["BORE_OIL_VOL"] / prod_db["ON_STREAM_HRS"].replace(0, np.nan)

# Annual summary table
annual_summary = prod_db.groupby(prod_db["DATEPRD"].dt.year).agg({
    "BORE_OIL_VOL": "sum",
    "BORE_GAS_VOL": "sum",
    "BORE_WAT_VOL": "sum",
    "ON_STREAM_HRS": "sum"
}).reset_index().rename(columns={"DATEPRD": "YEAR"})

annual_summary.to_csv("/home/jovyan/outputs/tables/annual_production_summary.csv", index=False)
annual_summary
# Out:
#    YEAR  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  ON_STREAM_HRS
# 0  2008    1764375.15  2.570386e+08      23523.13    10956.21667
# 1  2009    2684392.04  3.759820e+08     232104.69    15773.60329
# 2  2010    1689902.55  2.439484e+08    1887594.78    16189.99996
# 3  2011     847965.40  1.303202e+08    2190640.28    13566.32334
# 4  2012     574206.33  9.020864e+07    2110118.66    14152.34166
# 5  2013     558012.53  8.758778e+07    2576365.79    18435.00433
# 6  2014     743107.49  1.117919e+08    2716070.92    35121.82252
# 7  2015     861749.06  1.284238e+08    2009825.86    36573.94612
# 8  2016     313370.06  5.006913e+07    1572866.41    23996.39367

# %%
plt.figure(figsize=(14, 6))
field_daily = prod_db.groupby("DATEPRD")[["BORE_OIL_VOL", "BORE_WAT_VOL"]].sum().reset_index()

plt.plot(field_daily["DATEPRD"], field_daily["BORE_OIL_VOL"], label="Oil Production (Sm3/day)", color="green", alpha=0.7)
plt.plot(field_daily["DATEPRD"], field_daily["BORE_WAT_VOL"], label="Water Production (Sm3/day)", color="blue", alpha=0.7)
plt.title("Volve Field Daily Production (Oil vs Water Decline Trend)")
plt.xlabel("Date")
plt.ylabel("Volume (Sm3)")
plt.legend()
plt.tight_layout()
plt.savefig("/home/jovyan/outputs/figures/field_production_trend.png", dpi=300)
plt.show()

# %%
numeric_cols = ["BORE_OIL_VOL", "BORE_GAS_VOL", "BORE_WAT_VOL", "ON_STREAM_HRS", 
                "AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_CHOKE_SIZE_P", "AVG_WHP_P"]
available_cols = [c for c in numeric_cols if c in prod_db.columns]

plt.figure(figsize=(10, 8))
sns.heatmap(prod_db[available_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f", vmin=-1, vmax=1)
plt.title("Correlation Matrix of Production Variables")
plt.tight_layout()
plt.savefig("/home/jovyan/outputs/figures/correlation_heatmap.png", dpi=300)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.inspection import permutation_importance
import joblib

ml_df = prod_db.sort_values(["NPD_WELL_BORE_NAME", "DATEPRD"]).copy()

# Well-aware 1-day lag creation
lag_candidates = ["BORE_OIL_VOL", "BORE_GAS_VOL", "BORE_WAT_VOL", "ON_STREAM_HRS", "AVG_DOWNHOLE_PRESSURE", "AVG_CHOKE_SIZE_P"]
for col in lag_candidates:
    if col in ml_df.columns:
        ml_df[f"{col}_LAG_1"] = ml_df.groupby("NPD_WELL_BORE_NAME")[col].shift(1)

# Calendar features
ml_df["MONTH"] = ml_df["DATEPRD"].dt.month
ml_df["DAY_OF_YEAR"] = ml_df["DATEPRD"].dt.dayofyear
ml_df["DAYS_FROM_START"] = (ml_df["DATEPRD"] - ml_df["DATEPRD"].min()).dt.days

feature_cols = [c for c in ml_df.columns if "_LAG_1" in c] + ["MONTH", "DAY_OF_YEAR", "DAYS_FROM_START"]
ml_clean = ml_df.dropna(subset=feature_cols + ["BORE_OIL_VOL"]).copy()

# Chronological split: train up to 2015-01-15, test after
train_mask = ml_clean["DATEPRD"] <= "2015-01-15"
test_mask = ml_clean["DATEPRD"] > "2015-01-15"

X_train, y_train = ml_clean.loc[train_mask, feature_cols], ml_clean.loc[train_mask, "BORE_OIL_VOL"]
X_test, y_test = ml_clean.loc[test_mask, feature_cols], ml_clean.loc[test_mask, "BORE_OIL_VOL"]

print(f"Train size: {X_train.shape[0]} samples | Test size: {X_test.shape[0]} samples")
# Out:
# Train size: 5825 samples | Test size: 2906 samples

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "HistGradientBoosting": HistGradientBoostingRegressor(random_state=42)
}

results = []
fitted_models = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    fitted_models[name] = model
    
    mae = mean_absolute_error(y_test, preds)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds)
    
    results.append({"Model": name, "MAE": round(mae, 2), "RMSE": round(rmse, 2), "R2": round(r2, 4)})

results_df = pd.DataFrame(results)
results_df.to_csv("/home/jovyan/outputs/tables/model_comparison_metrics.csv", index=False)
print(results_df)

# Save best model
best_model = fitted_models["HistGradientBoosting"]
joblib.dump(best_model, "/home/jovyan/outputs/best_forecasting_model.joblib")
# Out:
#                   Model     MAE    RMSE      R2
# 0     Linear Regression  120.13  150.74  0.8756
# 1         Random Forest   86.82  133.07  0.9030
# 2  HistGradientBoosting   61.52  103.38  0.9415
# ['/home/jovyan/outputs/best_forecasting_model.joblib']

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))

# Actual vs Predicted Plot
test_preds = best_model.predict(X_test)
ax[0].scatter(y_test, test_preds, alpha=0.5, color="teal")
ax[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], "r--", lw=2)
ax[0].set_title("Actual vs Predicted Daily Oil Volume (HistGradientBoosting)")
ax[0].set_xlabel("Actual BORE_OIL_VOL (Sm3)")
ax[0].set_ylabel("Predicted BORE_OIL_VOL (Sm3)")

# Permutation Importance
perm = permutation_importance(best_model, X_test, y_test, n_repeats=10, random_state=42)
sorted_idx = perm.importances_mean.argsort()
ax[1].barh(np.array(feature_cols)[sorted_idx], perm.importances_mean[sorted_idx], color="navy")
ax[1].set_title("Feature Permutation Importance (Predictive Signal)")
ax[1].set_xlabel("Mean Importance")

plt.tight_layout()
plt.savefig("/home/jovyan/outputs/figures/model_evaluation_and_importance.png", dpi=300)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score

# Aggregate to well-month observations
monthly_agg = prod_db.groupby(["NPD_WELL_BORE_NAME", prod_db["DATEPRD"].dt.to_period("M")]).agg({
    "BORE_OIL_VOL": "sum",
    "BORE_GAS_VOL": "sum",
    "BORE_WAT_VOL": "sum",
    "ON_STREAM_HRS": "sum"
}).reset_index()

monthly_agg["WATER_CUT"] = monthly_agg["BORE_WAT_VOL"] / (monthly_agg["BORE_OIL_VOL"] + monthly_agg["BORE_WAT_VOL"]).replace(0, np.nan)
monthly_agg["GOR"] = monthly_agg["BORE_GAS_VOL"] / monthly_agg["BORE_OIL_VOL"].replace(0, np.nan)
monthly_agg["OIL_PER_HR"] = monthly_agg["BORE_OIL_VOL"] / monthly_agg["ON_STREAM_HRS"].replace(0, np.nan)
monthly_agg = monthly_agg.fillna(0)

cluster_features = ["BORE_OIL_VOL", "BORE_GAS_VOL", "BORE_WAT_VOL", "ON_STREAM_HRS", "WATER_CUT", "GOR", "OIL_PER_HR"]
scaler = StandardScaler()
X_cluster_scaled = scaler.fit_transform(monthly_agg[cluster_features])

# Silhouette Score comparison across K
print("--- Silhouette Scores across K ---")
for k in range(2, 6):
    km = KMeans(n_clusters=k, random_state=42, n_init=10).fit(X_cluster_scaled)
    score = silhouette_score(X_cluster_scaled, km.labels_)
    print(f"K = {k} | Silhouette Score: {score:.4f}")

# Fit final 2 clusters
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10).fit(X_cluster_scaled)
ward = AgglomerativeClustering(n_clusters=2, linkage="ward").fit(X_cluster_scaled)

monthly_agg["KMeans_Cluster"] = kmeans.labels_
monthly_agg["Ward_Cluster"] = ward.labels_

monthly_agg.to_csv("/home/jovyan/outputs/tables/clustered_monthly_production.csv", index=False)
print("\nClustering complete. Results saved to tables/clustered_monthly_production.csv")
# Out:
# --- Silhouette Scores across K ---
# K = 2 | Silhouette Score: 0.4602
# K = 3 | Silhouette Score: 0.5291
# K = 4 | Silhouette Score: 0.4340
# K = 5 | Silhouette Score: 0.4612
#
# Clustering complete. Results saved to tables/clustered_monthly_production.csv
